# %% [markdown]
# <a id='top'></a>
#
# # CSCI 3022: Intro to Data Science - Spring 2021 Practicum 2
# ***
#
#
# **Here are the rules:**
#
# 1. All work, code and analysis, must be your own.
# 2. You may use your course notes, posted lecture slides, textbooks, in-class notebooks, and homework solutions as resources.  You may also search online for answers to general knowledge questions like the form of a probability distribution function or how to perform a particular operation in Python/Pandas.
# 3. This is meant to be like a coding portion of your midterm exam. So, the instructional team will be a bit less helpful than we typically are with homework. For example, we will not check answers, significantly debug your code, and so on.  But please don't feel like you're totally alone on this: **feel free to ask questions or ask for help**, and we will decide how best to provide that assistance.
# 4. If something is left open-ended, it is because we want to see how you approach the kinds of problems you will encounter in the wild, where it will not always be clear what sort of tests/methods should be applied. Feel free to ask clarifying questions though.
# 5. You may **NOT** post to message boards or other online resources asking for help, except Piazza.
# 6. You may **NOT** copy-paste solutions *from anywhere*.
# 7. You may **NOT** collaborate with classmates or anyone else.
# 8. In short, **your work must be your own**. It really is that simple.
#
# Violation of the above rules will result in an immediate academic sanction (*at the very least*, you will receive a 0 on this practicum or an F in the course, depending on severity), and a trip to the Honor Code Council.
#
# **By submitting this assignment, you agree to abide by the rules given above.**
#
# ***
#
# **NOTES**:
#
# - You may not use late days on the practicums nor can you drop your practicum grades.
# - If you have a question for us, post it as a **PRIVATE** message on Piazza.  If we decide that the question is appropriate for the entire class, then we will add it to a Practicum clarifications thread.
# - Do **NOT** load or use any Python packages that are not available in Anaconda 3.6. The practicum is designed to be completed using only the packages in the first given code cell.
# - Some problems with code may be autograded.  If we provide a function API **do not** change it.  If we do not provide a function API then you're free to structure your code however you like.
# - Submit only this Jupyter notebook to Canvas.  Do not compress it using tar, rar, zip, etc.
# - This should go without saying, but... For any question that asks you to calculate something, you **must show all work to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
#
# ---
# **Shortcuts:**  [Problem 1](#p1) | [Problem 2](#p2) | [Bottom](#bot)
#
# ---

# %%
##Get them stats in here
import numpy as np 
import pandas as pd 
from scipy import stats
import statsmodels.api as sm
import matplotlib.pylab as plt 
from patsy import dmatrices
import seaborn as sns
import itertools
# %matplotlib inline

# %% [markdown]
# <br>
#
# ---
# [Back to top](#top)
# <a id='p1'></a>
#
# ## [50 points] Problem 1: What makes a good shuffle?
#
# Our goal in this problem is understand something about the statistics of shuffling: what makes a good shuffle?  Can we compare the order of cards in the deck to an original (sorted) order to determine whether or not the deck appears randomized?
#
# In all cases in this problem, we can view a deck as having all unique cards: the standard 52-card playing deck could be represented by integer card identifiers $[0, 1, 2, 3, \dots, 51]$, and a *shuffle* of the deck is a random *permutation* of those 52 indentifiers.
#
# In part 1 of this problem, we explore a sample statistic that reduces the order of the cards into a single measurement.

# %% [markdown]
# ### Problem 1 Part 1: The Statistic
# ** Part 1 A: Implementing the statistic.**
#
# The most common *single* statistic used for tracking the randomness of a shuffle is the count of *rising sequences* in that list's indices.  A rising sequence is a sequence of cards that appear in the same order that they did in the original deck, even if some other cards are in between.  For example, if the deck is represented by integers 0-10, card '1' will be part of the same rising sequence as card '0' as long as '1' occurs after '0' in the shuffled deck.  '2' would be part of the same sequence as long as it is after '1'.
#
# A visualization of counting these can be found on page 2 [of this paper](https://statweb.stanford.edu/~cgates/PERSI/papers/bayer92.pdf).  **Look over the images in the paper before proceeding.**
#
#
#
# Implement the `rising_seqs` function that takes in a list of integers and returns the number of rising sequences of that list.
#
# Overview of the function:
# - Find the indices for the permutation of deck that *would* represent a perfect sort of the deck.   Check `np.argsort` for a quick way to do this.  For example, the deck [3,0,2,1] has sorted permutation of [1,3,2,0], since we find the value 0 in index 1, then the value 1 in index 3, and so forth.
# - Count the number of times that the indices in this permutation decrease; e.g. the number of times that index $i$ has a value *more* than index $i+1$.  This represents a location where in the **shuffled** deck, a rising sequence would have been broken or ended, requiring us to start a new sequence.  The total count of rising sequences is 1 plus this value.
# - Return the number of rising sequences.
# - You may assume the deck's values are all integers and begin at 0, although neither assumption should be necessary.

# %%
def rising_seqs(deck):
    covered = [False] * len(deck)
    dropsTemp = []
    for i, c in enumerate(deck):
        if covered[i] != 0:
            continue
        seq = []        
        curr = c
        idx = i
        
        while True:
            try:
                idx = deck.tolist().index(curr+1, idx+1)
                curr = deck[idx]
                seq.append(curr)
                covered[idx] = 1
            except ValueError:
                break
        dropsTemp.append(seq)
        drops = len(dropsTemp)
        
    return drops



test1=rising_seqs(np.array([0, 1, 2, 3, 4, 5, 6, 7]))
print(test1)
# Out:
# 1

# %% [markdown]
# ** Part 1 B: Trying out the statistic.**
#
# Try out your statistic on a few quick test cases to make sure it's working.
#
# Some examples to sanity check your function.
# - [0,1,2,3,4,5,6,7] has only one rising sequence.
# - [7,6,5,4,3,2,1,0] has 8 rising sequences: each term is its own.
# - [3,1,2,0] has 3 rising sequence: [0], [1,2], [3].
# - [0,2,3,5,1,4,7,6] has the 4 rising sequences of [0,1], [2,3,4], [5,6], and [7].

# %%
test1=rising_seqs(np.array([0, 1, 2, 3, 4, 5, 6, 7]))
assert test1 == 1, 'Failed check 1'

test2=rising_seqs(np.array([7,6,5,4,3,2,1,0]))
assert test2 == 8, 'Failed check 2'

test3=rising_seqs(np.array([3,1,2,0]))
assert test3 == 3, 'Failed check 3'

test4=rising_seqs(np.array([0,2,3,5,1,4,7,6]))
assert test4 == 4, 'Failed check 4'

# %% [markdown]
# ** Part 1 C: Bootstrapping.**
#
# What represents a well shuffled deck?  Take a 52-card deck (or the integer list $[0,1,2,\dots ,51]$) and use np.random.shuffle or np.random.permutation to generate 10000 random permutations.  For each, compute and save their counts of rising sequences.
#
# Make a histogram of those rising sequences and print out the mean, 2.5\% percentile and 97.5\% percentile.

# %%
tempDeck = np.array(range(52))
seqTotal = []
for i in range(10000):
    np.random.shuffle(tempDeck)
    seqTotal.append(rising_seqs(tempDeck))
plt.hist(seqTotal)
plt.title("Rising Sequences Histogram")
plt.xlabel("# of Rising Seqs")
plt.ylabel("Frequency")
print("Mean: ", np.mean(seqTotal))
print("2.5 Percentile: ", np.percentile(seqTotal, 2.5))
print("97.5 Percentile: ", np.percentile(seqTotal, 97.5))
# Out:
# Mean:  26.5253
# 2.5 Percentile:  22.0
# 97.5 Percentile:  31.0

# %% [markdown]
# When would we decide that a given ordering is not a good shuffle?** Part 1 D: The Bootstrapped test.**
#
# We wish to test the null hypothesis "the deck is well-shuffled" against the alternative "the deck is not well-shuffled," using the *test statistic* of rising sequences.  In plain English, what is the *rejection rejection* of such a test?  When would we decide that a given ordering is not a good shuffle?  Use a 95% significance, as suggested by the interval in part 1C.

# %% [markdown]
# ***
# When there are a minimal amount of rising sequences, there would be a rejection of such a test. We would decide that a given ordering is not a good shuffle if all possible arangements of the deck are not equally likely. If we were to use a 95% significance level, the null hypothesis would be rejected (when p < 0.05).

# %% [markdown]
# ### Problem 1 Part 2: How to Shuffle
#
# A "perfect riffle" shuffle is a shuffle in which a deck is divided exactly in half, and then a new deck order is formed by alternating one-card-at-a-time from each half.  Depending on whether or not the top or first card of the interleaving came from the top half of the deck or the bottom half of the deck this is called an *out-shuffle* or *in-shuffle*, respectively.
#
# ** Part 2 A: The out-shuffle.**
#
# Write a function that performs a perfect out-shuffle of a deck.  This function should take an ordered list of length $n$ and:
#
# - breaks the deck in half, with the "top" of the deck being the first $n/2$ elements and the "bottom" of the deck being the last $n/2$ elements.
# - creates a new ordered list generated by interweaving one card from the top pile, *then* one card from the "bottom" pile, etc.  The top/first card comes from the "top" elements and the bottom/last card comes from the "bottom" pile.
#
# You may for convenience assume that there are an even number of cards in the deck.
#
# (Note and sanity check: a perfect out-shuffle on a deck with an even number of cards will always have the first card of the input ordering remain the first card of the output ordering, and the input last card remain the last card)
# .
# In the suggested API:
#  - deck is a numpy array of integers (or floats) from 0 to (n-1) for a deck of length n.  Consider using np.array(range(n)) if you want to initialize a sorted deck.
#  - Return statement is a numpy array of the same form

# %%
#recommended API for checks:
def out_shuffle(deck):
    tempDeck = deck.tolist()
    half = len(deck) // 2
    otherHalf = tempDeck[half:]
    tempDeck = tempDeck[:half]
    
    for i, j in enumerate(tempDeck):
        otherHalf.insert((i*2), j)
    otherHalf = np.array(otherHalf)
    return otherHalf

out_shuffle(np.array(range(10))) #sanity check: should be 0-5-1-6...
# Out:
# array([0, 5, 1, 6, 2, 7, 3, 8, 4, 9])

# %% [markdown]
# ** Part 2 B: Counting out-shuffles.**
#
# How much are we supposed to shuffle?  Beginning with a sorted deck $[0,1,2,\dots ,51]$, perform out-shuffles 52 times *in a row*, where the result of one shuffle is used as the input/start for another.  For each resulting state of the deck, do the following:
#
# - save the number of rising sequences in the deck
# - Perform a formal hypothesis test using the bootstrapped rejection region in part a): at 95\% confidence would we reject the null hypothesis that "the deck is well-shuffled?."
# - Compute a two-tailed p-value for the number of rising sequences in the deck.  In other words, what proportion of the time in the simulated `np.random.shuffle` shuffles did we observe a more extreme number of rising sequences?
#
# Make a plot with "number of perfect out shuffles" on the $x$-axis and "rising sequences" for the shuffle on the $y$-axis.  Include a visual indicator for when the number of rising sequences was *inside* or *outside* of the rejection region in part 1.
#
# Using this plot make a plain English statment answering the following: "What is the best number of shuffles to approximately randomize a sorted deck using out-shuffles?  Does it end up well randomized?"  Explain your answer.

# %%
totalCards = np.array(range(52))
seqTotal = []
tempDeck = []

tempDeck = np.array(range(52))
np.random.shuffle(tempDeck)

for i in range(52):
    totalCards = out_shuffle(totalCards)
    seqTotal.append(rising_seqs(totalCards))
    
print(stats.ttest_ind(tempDeck, seqTotal))

plt.plot(seqTotal)
plt.xlabel("# of Perfect Out Shuffles")
plt.ylabel("Rising Sequences")
# Out:
# Ttest_indResult(statistic=5.1372425735667715, pvalue=1.3444078747767518e-06)
# Text(0, 0.5, 'Rising Sequences')

# %% [markdown]
# ***
# The best number of shuffles to approximately randomize a sorted deck using out-shuffles would be about 4. If this deck was not perfectly sorted, then the number of out-shiffles needed would be around 8. This does end of well-randomized because the amount of rising sequences is between the interval needed for a deck to be considered well-randomized.

# %% [markdown]
# ** Part 2 C: In-shuffles.**
#
# Repeat parts 2A and 2B for in shuffles.  This means do the following:
#
# Write a function that performs a perfect in-shuffle of a deck.  This function should take an ordered list of length $n$ and:
#
# - breaks the deck in half, with the "top" of the deck being the first $n/2$ elements and the "bottom" of the deck being the last $n/2$ elements.
# - creates a new ordered list generated by interweaving one card from the bottom pile, *then* one card from the "top" pile, etc.  The top/first card comes from the "bottom" elements and the bottom/last card comes from the "top" pile.
#
# After this, repeat the plot and hypothesis tests made in part 2B for the in-shuffle.  Again, answer the prompt:  "What is the best number of shuffles to approximately randomize a sorted deck using in-shuffles?  Does it end up well randomized?"  Explain your answer.

# %%
#recommended API for checks:
def in_shuffle(deck):
    tempDeck = deck.tolist()
    half = len(deck) // 2
    otherHalf = tempDeck[half:]
    tempDeck = tempDeck[:half]
    
    for i, j in enumerate(tempDeck):
        otherHalf.insert((i*2+1), j)
    otherHalf = np.array(otherHalf)
    return otherHalf
#in_shuffle(np.array(range(10))) #sanity check: should be 5-0-6-1...

deck = np.array(range(52))
seqTotal = []
new = []

new = np.array(range(52))
np.random.shuffle(new)

for i in range(52):
    deck = in_shuffle(deck)
    seqTotal.append(rising_seqs(deck))
    
print(stats.ttest_ind(new, seqTotal))

plt.plot(seqTotal)
plt.xlabel("# of Perfect Out Shuffles")
plt.ylabel("Rising Sequences")
# Out:
# Ttest_indResult(statistic=-0.33646329245522655, pvalue=0.7372127583194235)
# Text(0, 0.5, 'Rising Sequences')

# %% [markdown]
# ***
# The best number of shuffles to approximately randomize a sorted deck using in-shuffles would be around 4 or 5. This does not end up well-randomized because, after 52 shuffles, the deck appears to be back in its original order.

# %% [markdown]
# ### Problem 1 Part 3: Noisy Shuffling; Extra Credit
# ** Part 3 A: Random shuffles; Extra Credit**
#
# **This part of the problem is for extra credit only.  It is not required.**
#
# One result of your analysis above should have been that "perfect" shuffles aren't great for getting a random deck - we only approximate randomness and eventually find our way back into the original sort. So how do we shuffle better?  Suppose that we divide our deck in half as we prepare to shuffle, but then *instead* of one-by-one interleaving the two piles, we choose a random number of cards from each pile before we move to the other pile.
#
# A variety of ways to describe this exist, but let's try one: Poissons.
#
# Create a function `rand_in_shuffle(deck, lambda)` that starts with your code for an in-shuffle.  However, instead of generating the shuffled deck by taking 1 card at a time from the bottom deck, then the top deck, and so forth, take
# $1+r$ cards from each pile, where $r \sim Poisson(\lambda)$ is i.i.d. for each instance you select cards form either pile.  Once you run out of cards in one pile, fill in the rest/bottom of the deck with the remaining cards in the other pile.
#
# Note that if $\lambda=0$, this should represent a perfect in-shuffle.  As $\lambda$ increases (appropriate values will likely be in $(0,2)$), our shuffle will more closely represent how a person actually shuffles.
#
# (Implementation hint: you may use the `.pop` function if you convert your deck to a list, but numpy has its own equivalent using `numpy.delete`.)

# %%
#recommended API for checks:
def rand_in_shuffle(deck, lam):
    return(new_deck)


#if lam=0, should be same as a regular in-shuffle
# print(rand_in_shuffle(np.array(range(10)), 0))
# print(in_shuffle(np.array(range(10))))

# %% [markdown]
# ** Part 3 B: Random shuffle scoring; Extra Credit**
#
# **This part of the problem is for extra credit only.  It is not required.**
#
# Using `rand_in_shuffle(deck, lambda)`, experiment with different $\lambda$ values ($\lambda \in [0,0.1,0.2,0.3,\dots 2.9,3.0])$ to attempt to answer the following: If we were going to perform *exactly 6* random in-shuffles, what value of $\lambda$ on average generates the deck that appears to be shuffled the most?  In other words, is there an amount of randomness that appears to be best in actually randomizing the deck?

# %% [markdown]
# <br>
#
# ---
# [Back to top](#top)
# <a id='p2'></a>
#
# ## [50 points] Problem 2: Multiple Linear Regression
#
# Load the data set in `houses`, with an opening snipper below.  The data includes sale prices of 24 houses from a midwetern town in the 1970's.   You are told that you need to quantify how price can be explained and predicted by the feature of the house.
#
# The variables available in the data set are labeled as follows:
#
# * sales:    the sales price of the house (in 1000s of dollars)
# * tax: 	    the local taxes
# * bath: 	the number of bathrooms
# * lot: 	    the lot size (1000s of ft)
# * size: 	the living space (1000s of ft)
# * garage: 	number of parking spots in the garage
# * rooms: 	number of rooms
# * bedrooms: number of bedrooms
# * age: 	    age in years
# * fire: 	number of fireplaces

# %%
df=pd.read_csv('houses.txt', delimiter = "\t")
df.columns=['tax','bath','lot','size','garage','rooms','bedrooms','age','fire','sales']
df.head()
# Out:
#      tax  bath    lot   size  garage  rooms  bedrooms  age  fire  sales
# 0  4.918   1.0  3.472  0.998     1.0      7         4   42     0   25.9
# 1  5.021   1.0  3.531  1.500     2.0      7         4   62     0   29.5
# 2  4.543   1.0  2.275  1.175     1.0      6         3   40     0   27.9
# 3  4.557   1.0  4.050  1.232     1.0      6         3   54     0   25.9
# 4  5.060   1.0  4.455  1.121     1.0      6         3   42     0   29.9

# %% [markdown]
# ### Problem 2 Part 1: Fit your own model
# ** Part 1 A: Explore**
#
# Make pairwise scatter plots of the continuous predictors/covariates, both against each other and against the outcome (expenditures).   Does the relationship between the independent variables and the dependent variables appear to be linear?  Do there appear to be independent variables that are collinear?

# %%
sns.pairplot(df, vars = ['tax','lot','size','sales'])

# %% [markdown]
# ***
# The relationship between the independent variables and the dependent variables appear to be linear, more specifically, the relationships between lot, size, tax, and sales appear to be linear. Additionally, there are some independent variables that are collinear.

# %% [markdown]
# ** Part 1 B: Make a Model**
#
# After removing any reasonably choices for columns from your work in part 1A, fit a model with the remaining columns.  Print its summary table.

# %%
arr = ['tax','bath','lot','size','garage','rooms','bedrooms','age','fire','sales']
for x in range(len(arr)):
    for y in arr:
        m, intercept, rval, pval, std = stats.linregress(df[y], df[arr[x]])
        print("SLR: {} vs {}".format(y, arr[x]))
        print("Slope: {:.3f}".format(m))
        print("Intercept: {:.3f}".format(intercept))
        print("R-Val: {:.3f}".format(rval))
        print("P-Val: {:.3f}".format(pval))
        print("STD: {:.3f}".format(std))
        print("\n")
# Out:
# SLR: tax vs tax
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: bath vs tax
# Slope: 4.279
# Intercept: 1.413
# R-Val: 0.651
# P-Val: 0.001
# STD: 1.063
#
#
# SLR: lot vs tax
# Slope: 0.555
# Intercept: 3.057
# R-Val: 0.689
# P-Val: 0.000
# STD: 0.124
#
#
# SLR: size vs tax
# Slope: 4.205
# Intercept: 0.587
# R-Val: 0.734
# P-Val: 0.000
# STD: 0.829
#
#
# SLR: garage vs tax
# Slope: 1.200
# Intercept: 4.830
# R-Val: 0.459
# P-Val: 0.024
# STD: 0.496
#
#
# SLR: rooms vs tax
# Slope: 1.146
# Intercept: -1.041
# R-Val: 0.641
# P-Val: 0.001
# STD: 0.293
#
#
# SLR: bedrooms vs tax
# Slope: 1.029
# Intercept: 3.148
# R-Val: 0.367
# P-Val: 0.078
# STD: 0.556
#
#
# SLR: age vs tax
# Slope: -0.049
# Intercept: 8.250
# R-Val: -0.437
# P-Val: 0.033
# STD: 0.022
#
#
# SLR: fire vs tax
# Slope: 0.525
# Intercept: 6.274
# R-Val: 0.147
# P-Val: 0.494
# STD: 0.754
#
#
# SLR: sales vs tax
# Slope: 0.230
# Intercept: -1.557
# R-Val: 0.874
# P-Val: 0.000
# STD: 0.027
#
#
# SLR: tax vs bath
# Slope: 0.099
# Intercept: 0.532
# R-Val: 0.651
# P-Val: 0.001
# STD: 0.025
#
#
# SLR: bath vs bath
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: lot vs bath
# Slope: 0.051
# Intercept: 0.861
# R-Val: 0.413
# P-Val: 0.045
# STD: 0.024
#
#
# SLR: size vs bath
# Slope: 0.635
# Intercept: 0.288
# R-Val: 0.729
# P-Val: 0.000
# STD: 0.127
#
#
# SLR: garage vs bath
# Slope: 0.089
# Intercept: 1.050
# R-Val: 0.224
# P-Val: 0.293
# STD: 0.083
#
#
# SLR: rooms vs bath
# Slope: 0.139
# Intercept: 0.264
# R-Val: 0.510
# P-Val: 0.011
# STD: 0.050
#
#
# SLR: bedrooms vs bath
# Slope: 0.182
# Intercept: 0.591
# R-Val: 0.426
# P-Val: 0.038
# STD: 0.082
#
#
# SLR: age vs bath
# Slope: -0.002
# Intercept: 1.231
# R-Val: -0.101
# P-Val: 0.639
# STD: 0.004
#
#
# SLR: fire vs bath
# Slope: 0.111
# Intercept: 1.139
# R-Val: 0.204
# P-Val: 0.339
# STD: 0.114
#
#
# SLR: sales vs bath
# Slope: 0.028
# Intercept: 0.182
# R-Val: 0.710
# P-Val: 0.000
# STD: 0.006
#
#
# SLR: tax vs lot
# Slope: 0.856
# Intercept: 0.551
# R-Val: 0.689
# P-Val: 0.000
# STD: 0.192
#
#
# SLR: bath vs lot
# Slope: 3.370
# Intercept: 2.101
# R-Val: 0.413
# P-Val: 0.045
# STD: 1.584
#
#
# SLR: lot vs lot
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: size vs lot
# Slope: 4.065
# Intercept: 0.409
# R-Val: 0.572
# P-Val: 0.004
# STD: 1.244
#
#
# SLR: garage vs lot
# Slope: 0.665
# Intercept: 5.160
# R-Val: 0.205
# P-Val: 0.337
# STD: 0.678
#
#
# SLR: rooms vs lot
# Slope: 0.871
# Intercept: 0.372
# R-Val: 0.392
# P-Val: 0.058
# STD: 0.436
#
#
# SLR: bedrooms vs lot
# Slope: 0.528
# Intercept: 4.362
# R-Val: 0.152
# P-Val: 0.479
# STD: 0.733
#
#
# SLR: age vs lot
# Slope: -0.049
# Intercept: 7.882
# R-Val: -0.353
# P-Val: 0.091
# STD: 0.028
#
#
# SLR: fire vs lot
# Slope: 1.359
# Intercept: 5.693
# R-Val: 0.306
# P-Val: 0.146
# STD: 0.902
#
#
# SLR: sales vs lot
# Slope: 0.212
# Intercept: -1.295
# R-Val: 0.648
# P-Val: 0.001
# STD: 0.053
#
#
# SLR: tax vs size
# Slope: 0.128
# Intercept: 0.562
# R-Val: 0.734
# P-Val: 0.000
# STD: 0.025
#
#
# SLR: bath vs size
# Slope: 0.836
# Intercept: 0.408
# R-Val: 0.729
# P-Val: 0.000
# STD: 0.168
#
#
# SLR: lot vs size
# Slope: 0.080
# Intercept: 0.899
# R-Val: 0.572
# P-Val: 0.004
# STD: 0.025
#
#
# SLR: size vs size
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: garage vs size
# Slope: 0.164
# Intercept: 1.168
# R-Val: 0.359
# P-Val: 0.085
# STD: 0.091
#
#
# SLR: rooms vs size
# Slope: 0.212
# Intercept: 0.006
# R-Val: 0.679
# P-Val: 0.000
# STD: 0.049
#
#
# SLR: bedrooms vs size
# Slope: 0.281
# Intercept: 0.494
# R-Val: 0.574
# P-Val: 0.003
# STD: 0.085
#
#
# SLR: age vs size
# Slope: -0.003
# Intercept: 1.486
# R-Val: -0.139
# P-Val: 0.517
# STD: 0.004
#
#
# SLR: fire vs size
# Slope: 0.067
# Intercept: 1.367
# R-Val: 0.107
# P-Val: 0.620
# STD: 0.132
#
#
# SLR: sales vs size
# Slope: 0.033
# Intercept: 0.257
# R-Val: 0.708
# P-Val: 0.000
# STD: 0.007
#
#
# SLR: tax vs garage
# Slope: 0.175
# Intercept: 0.190
# R-Val: 0.459
# P-Val: 0.024
# STD: 0.072
#
#
# SLR: bath vs garage
# Slope: 0.563
# Intercept: 0.656
# R-Val: 0.224
# P-Val: 0.293
# STD: 0.522
#
#
# SLR: lot vs garage
# Slope: 0.063
# Intercept: 0.933
# R-Val: 0.205
# P-Val: 0.337
# STD: 0.064
#
#
# SLR: size vs garage
# Slope: 0.785
# Intercept: 0.226
# R-Val: 0.359
# P-Val: 0.085
# STD: 0.435
#
#
# SLR: garage vs garage
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: rooms vs garage
# Slope: 0.403
# Intercept: -1.306
# R-Val: 0.589
# P-Val: 0.002
# STD: 0.118
#
#
# SLR: bedrooms vs garage
# Slope: 0.580
# Intercept: -0.523
# R-Val: 0.541
# P-Val: 0.006
# STD: 0.192
#
#
# SLR: age vs garage
# Slope: -0.001
# Intercept: 1.345
# R-Val: -0.020
# P-Val: 0.925
# STD: 0.009
#
#
# SLR: fire vs garage
# Slope: 0.139
# Intercept: 1.278
# R-Val: 0.102
# P-Val: 0.637
# STD: 0.290
#
#
# SLR: sales vs garage
# Slope: 0.046
# Intercept: -0.294
# R-Val: 0.461
# P-Val: 0.023
# STD: 0.019
#
#
# SLR: tax vs rooms
# Slope: 0.358
# Intercept: 4.206
# R-Val: 0.641
# P-Val: 0.001
# STD: 0.092
#
#
# SLR: bath vs rooms
# Slope: 1.875
# Intercept: 4.312
# R-Val: 0.510
# P-Val: 0.011
# STD: 0.674
#
#
# SLR: lot vs rooms
# Slope: 0.177
# Intercept: 5.435
# R-Val: 0.392
# P-Val: 0.058
# STD: 0.088
#
#
# SLR: size vs rooms
# Slope: 2.174
# Intercept: 3.492
# R-Val: 0.679
# P-Val: 0.000
# STD: 0.501
#
#
# SLR: garage vs rooms
# Slope: 0.862
# Intercept: 5.368
# R-Val: 0.589
# P-Val: 0.002
# STD: 0.252
#
#
# SLR: rooms vs rooms
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: bedrooms vs rooms
# Slope: 1.364
# Intercept: 2.182
# R-Val: 0.870
# P-Val: 0.000
# STD: 0.164
#
#
# SLR: age vs rooms
# Slope: 0.008
# Intercept: 6.207
# R-Val: 0.124
# P-Val: 0.563
# STD: 0.013
#
#
# SLR: fire vs rooms
# Slope: 0.444
# Intercept: 6.389
# R-Val: 0.222
# P-Val: 0.297
# STD: 0.416
#
#
# SLR: sales vs rooms
# Slope: 0.078
# Intercept: 3.808
# R-Val: 0.528
# P-Val: 0.008
# STD: 0.027
#
#
# SLR: tax vs bedrooms
# Slope: 0.131
# Intercept: 2.327
# R-Val: 0.367
# P-Val: 0.078
# STD: 0.071
#
#
# SLR: bath vs bedrooms
# Slope: 1.000
# Intercept: 2.000
# R-Val: 0.426
# P-Val: 0.038
# STD: 0.452
#
#
# SLR: lot vs bedrooms
# Slope: 0.044
# Intercept: 2.904
# R-Val: 0.152
# P-Val: 0.479
# STD: 0.061
#
#
# SLR: size vs bedrooms
# Slope: 1.174
# Intercept: 1.543
# R-Val: 0.574
# P-Val: 0.003
# STD: 0.357
#
#
# SLR: garage vs bedrooms
# Slope: 0.506
# Intercept: 2.503
# R-Val: 0.541
# P-Val: 0.006
# STD: 0.167
#
#
# SLR: rooms vs bedrooms
# Slope: 0.556
# Intercept: -0.444
# R-Val: 0.870
# P-Val: 0.000
# STD: 0.067
#
#
# SLR: bedrooms vs bedrooms
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: age vs bedrooms
# Slope: 0.013
# Intercept: 2.694
# R-Val: 0.314
# P-Val: 0.136
# STD: 0.008
#
#
# SLR: fire vs bedrooms
# Slope: -0.000
# Intercept: 3.167
# R-Val: -0.000
# P-Val: 1.000
# STD: 0.272
#
#
# SLR: sales vs bedrooms
# Slope: 0.026
# Intercept: 2.251
# R-Val: 0.282
# P-Val: 0.183
# STD: 0.019
#
#
# SLR: tax vs age
# Slope: -3.879
# Intercept: 62.305
# R-Val: -0.437
# P-Val: 0.033
# STD: 1.702
#
#
# SLR: bath vs age
# Slope: -5.875
# Intercept: 44.312
# R-Val: -0.101
# P-Val: 0.639
# STD: 12.369
#
#
# SLR: lot vs age
# Slope: -2.521
# Intercept: 52.666
# R-Val: -0.353
# P-Val: 0.091
# STD: 1.426
#
#
# SLR: size vs age
# Slope: -7.069
# Intercept: 47.238
# R-Val: -0.139
# P-Val: 0.517
# STD: 10.730
#
#
# SLR: garage vs age
# Slope: -0.468
# Intercept: 38.073
# R-Val: -0.020
# P-Val: 0.925
# STD: 4.950
#
#
# SLR: rooms vs age
# Slope: 1.972
# Intercept: 24.639
# R-Val: 0.124
# P-Val: 0.563
# STD: 3.357
#
#
# SLR: bedrooms vs age
# Slope: 7.795
# Intercept: 12.773
# R-Val: 0.314
# P-Val: 0.136
# STD: 5.034
#
#
# SLR: age vs age
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: fire vs age
# Slope: 7.167
# Intercept: 35.667
# R-Val: 0.226
# P-Val: 0.289
# STD: 6.593
#
#
# SLR: sales vs age
# Slope: -0.928
# Intercept: 69.593
# R-Val: -0.397
# P-Val: 0.054
# STD: 0.457
#
#
# SLR: tax vs fire
# Slope: 0.041
# Intercept: -0.013
# R-Val: 0.147
# P-Val: 0.494
# STD: 0.059
#
#
# SLR: bath vs fire
# Slope: 0.375
# Intercept: -0.187
# R-Val: 0.204
# P-Val: 0.339
# STD: 0.383
#
#
# SLR: lot vs fire
# Slope: 0.069
# Intercept: -0.166
# R-Val: 0.306
# P-Val: 0.146
# STD: 0.046
#
#
# SLR: size vs fire
# Slope: 0.171
# Intercept: 0.014
# R-Val: 0.107
# P-Val: 0.620
# STD: 0.339
#
#
# SLR: garage vs fire
# Slope: 0.074
# Intercept: 0.152
# R-Val: 0.102
# P-Val: 0.637
# STD: 0.155
#
#
# SLR: rooms vs fire
# Slope: 0.111
# Intercept: -0.472
# R-Val: 0.222
# P-Val: 0.297
# STD: 0.104
#
#
# SLR: bedrooms vs fire
# Slope: -0.000
# Intercept: 0.250
# R-Val: -0.000
# P-Val: 1.000
# STD: 0.167
#
#
# SLR: age vs fire
# Slope: 0.007
# Intercept: -0.016
# R-Val: 0.226
# P-Val: 0.289
# STD: 0.007
#
#
# SLR: fire vs fire
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000
#
#
# SLR: sales vs fire
# Slope: 0.020
# Intercept: -0.430
# R-Val: 0.267
# P-Val: 0.207
# STD: 0.015
#
#
# SLR: tax vs sales
# Slope: 3.322
# Intercept: 13.355
# R-Val: 0.874
# P-Val: 0.000
# STD: 0.394
#
#
# SLR: bath vs sales
# Slope: 17.725
# Intercept: 13.950
# R-Val: 0.710
# P-Val: 0.000
# STD: 3.750
#
#
# SLR: lot vs sales
# Slope: 1.982
# Intercept: 22.672
# R-Val: 0.648
# P-Val: 0.001
# STD: 0.497
#
#
# SLR: size vs sales
# Slope: 15.404
# Intercept: 13.317
# R-Val: 0.708
# P-Val: 0.000
# STD: 3.278
#
#
# SLR: garage vs sales
# Slope: 4.590
# Intercept: 28.605
# R-Val: 0.461
# P-Val: 0.023
# STD: 1.881
#
#
# SLR: rooms vs sales
# Slope: 3.592
# Intercept: 11.283
# R-Val: 0.528
# P-Val: 0.008
# STD: 1.230
#
#
# SLR: bedrooms vs sales
# Slope: 2.998
# Intercept: 25.136
# R-Val: 0.282
# P-Val: 0.183
# STD: 2.178
#
#
# SLR: age vs sales
# Slope: -0.170
# Intercept: 41.004
# R-Val: -0.397
# P-Val: 0.054
# STD: 0.084
#
#
# SLR: fire vs sales
# Slope: 3.628
# Intercept: 33.722
# R-Val: 0.267
# P-Val: 0.207
# STD: 2.793
#
#
# SLR: sales vs sales
# Slope: 1.000
# Intercept: 0.000
# R-Val: 1.000
# P-Val: 0.000
# STD: 0.000

# %% [markdown]
# ** Part 1 C: Validate your Model**
#
#
# Perform a thorough discussion of the underlying regression assumptions of your model in part 1B.  You should plot a predictor vs. residuals plot for each column and histogram OR qqplot of the overall residuals.  Make sure to also check for non-linearity.

# %%
x,y = dmatrices('sales ~ tax + lot + size', data = df, return_type = 'dataframe')
sm.qqplot(sm.OLS(x,y).fit().resid, stats.t, distargs = (len(x),), line = 'r')

# %%
x,y = dmatrices('tax ~ lot + sales + size', data = df, return_type = 'dataframe')
sm.qqplot(sm.OLS(x,y).fit().resid, stats.t, distargs = (len(x),), line = 'r')

# %%
x,y = dmatrices('lot ~ tax + sales + size', data = df, return_type = 'dataframe')
sm.qqplot(sm.OLS(x,y).fit().resid, stats.t, distargs = (len(x),), line = 'r')

# %%
x,y = dmatrices('size ~ tax + sales + lot', data = df, return_type = 'dataframe')
sm.qqplot(sm.OLS(x,y).fit().resid, line = 'r')

# %% [markdown]
# ** Part 1 D: Tune your Model**
#
#
# Based on your work in parts 1B and 1C, **iterate** on your model.  Remove terms or add higher-order polynomials one at a time unless you are satisfied that your model captures the data as well as possible.  Each time you add or subtract a term from your model, you should repeat the steps in parts B and C: a summary table an exploration of assumptions.

# %% [markdown]
# ***
# I am satisfied that my model captures the data as well as possible. Even though some graphs show outliers, they don't make a significant difference in the results and outliers are to be expected in graphs like these.

# %% [markdown]
# ** Part 1 E: Explain your Model**
#
# **Justify** your choices: there are a lot of ways to choose a "best" model: we've mentioned e.g. only including significant predictors versus F-tests versus optimizing R-squared.  Explain what terms you chose and why they were appropriate!

# %% [markdown]
# ***
# The terms I chose were size, tax, sales, and lot because they remained true despite the underlying regression assumptions that were present. Additionally, these terms provided fairly linear relationships, which made analysis a bit easier compared to the other terms. P-value was also an important statistic that I looked at, because the p-values were all < 0.05 -- which was interesting to me.

# %% [markdown]
# ### Problem 2 Part 2: Let your Computer do it
#
# There are many methods to automate the analysis we did in part 1 of this problem.  These methods are never going to be as good as using your own eyes, but your computer is pretty powerful!
#
# Use `itertools.combinations` to perform a linear model (with no higher-order terms) on **every possible subset** of the 9 predictor variables to explain `sales`.  Report the one with the highest adjusted R-squared.

# %%
#usage: all the combinations of size 2 of the given list.
#your task: modify it to include the columns of the data frame, and ALL possible sizes
# then fit a model for each and save/find the best adjusted R-squared

linearModel = list(itertools.combinations(pd.DataFrame(columns = list(df)).columns, 2))
tempArr = []

for i, j in linearModel:
    subsets = sm.OLS(df[i],df[j]).fit()
    tempArr.append(subsets)
    
for i in range(len(tempArr)):
    sm.qqplot(tempArr[i].resid, line = 'r')
    print(tempArr[i].summary(), "\n")
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.966
# Model:                            OLS   Adj. R-squared (uncentered):              0.965
# Method:                 Least Squares   F-statistic:                              661.3
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.89e-18
# Time:                        03:37:12   Log-Likelihood:                         -38.591
# No. Observations:                  24   AIC:                                      79.18
# Df Residuals:                      23   BIC:                                      80.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bath           5.4424      0.212     25.716      0.000       5.005       5.880
# ==============================================================================
# Omnibus:                        9.448   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                7.553
# Skew:                           1.057   Prob(JB):                       0.0229
# Kurtosis:                       4.756   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.951
# Model:                            OLS   Adj. R-squared (uncentered):              0.949
# Method:                 Least Squares   F-statistic:                              447.8
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.41e-16
# Time:                        03:37:12   Log-Likelihood:                         -43.079
# No. Observations:                  24   AIC:                                      88.16
# Df Residuals:                      23   BIC:                                      89.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lot            1.0149      0.048     21.161      0.000       0.916       1.114
# ==============================================================================
# Omnibus:                        6.341   Durbin-Watson:                   1.589
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                4.588
# Skew:                          -0.665   Prob(JB):                        0.101
# Kurtosis:                       4.679   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.974
# Model:                            OLS   Adj. R-squared (uncentered):              0.973
# Method:                 Least Squares   F-statistic:                              870.3
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    8.81e-20
# Time:                        03:37:12   Log-Likelihood:                         -35.393
# No. Observations:                  24   AIC:                                      72.79
# Df Residuals:                      23   BIC:                                      73.96
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# size           4.6136      0.156     29.501      0.000       4.290       4.937
# ==============================================================================
# Omnibus:                        0.127   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.938   Jarque-Bera (JB):                0.339
# Skew:                          -0.087   Prob(JB):                        0.844
# Kurtosis:                       2.445   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.866
# Model:                            OLS   Adj. R-squared (uncentered):              0.860
# Method:                 Least Squares   F-statistic:                              148.1
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.67e-11
# Time:                        03:37:12   Log-Likelihood:                         -55.223
# No. Observations:                  24   AIC:                                      112.4
# Df Residuals:                      23   BIC:                                      113.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# garage         4.2581      0.350     12.171      0.000       3.534       4.982
# ==============================================================================
# Omnibus:                        0.091   Durbin-Watson:                   2.433
# Prob(Omnibus):                  0.955   Jarque-Bera (JB):                0.150
# Skew:                           0.114   Prob(JB):                        0.928
# Kurtosis:                       2.688   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.966
# Method:                 Least Squares   F-statistic:                              673.9
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.54e-18
# Time:                        03:37:12   Log-Likelihood:                         -38.372
# No. Observations:                  24   AIC:                                      78.74
# Df Residuals:                      23   BIC:                                      79.92
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rooms          0.9882      0.038     25.960      0.000       0.909       1.067
# ==============================================================================
# Omnibus:                        1.223   Durbin-Watson:                   0.652
# Prob(Omnibus):                  0.542   Jarque-Bera (JB):                0.861
# Skew:                          -0.039   Prob(JB):                        0.650
# Kurtosis:                       2.076   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.945
# Model:                            OLS   Adj. R-squared (uncentered):              0.943
# Method:                 Least Squares   F-statistic:                              398.7
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    5.01e-16
# Time:                        03:37:12   Log-Likelihood:                         -44.400
# No. Observations:                  24   AIC:                                      90.80
# Df Residuals:                      23   BIC:                                      91.98
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bedrooms       1.9932      0.100     19.968      0.000       1.787       2.200
# ==============================================================================
# Omnibus:                        0.370   Durbin-Watson:                   0.778
# Prob(Omnibus):                  0.831   Jarque-Bera (JB):                0.382
# Skew:                          -0.253   Prob(JB):                        0.826
# Kurtosis:                       2.646   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.769
# Model:                            OLS   Adj. R-squared (uncentered):              0.759
# Method:                 Least Squares   F-statistic:                              76.71
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    8.76e-09
# Time:                        03:37:12   Log-Likelihood:                         -61.705
# No. Observations:                  24   AIC:                                      125.4
# Df Residuals:                      23   BIC:                                      126.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.1449      0.017      8.758      0.000       0.111       0.179
# ==============================================================================
# Omnibus:                        0.513   Durbin-Watson:                   0.771
# Prob(Omnibus):                  0.774   Jarque-Bera (JB):                0.546
# Skew:                           0.299   Prob(JB):                        0.761
# Kurtosis:                       2.567   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.266
# Model:                            OLS   Adj. R-squared (uncentered):              0.234
# Method:                 Least Squares   F-statistic:                              8.339
# Date:                Sun, 02 May 2021   Prob (F-statistic):                     0.00830
# Time:                        03:37:12   Log-Likelihood:                         -75.593
# No. Observations:                  24   AIC:                                      153.2
# Df Residuals:                      23   BIC:                                      154.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# fire           6.7983      2.354      2.888      0.008       1.928      11.668
# ==============================================================================
# Omnibus:                        2.200   Durbin-Watson:                   0.837
# Prob(Omnibus):                  0.333   Jarque-Bera (JB):                1.903
# Skew:                          -0.630   Prob(JB):                        0.386
# Kurtosis:                       2.439   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    tax   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                              1550.
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.31e-22
# Time:                        03:37:12   Log-Likelihood:                         -28.601
# No. Observations:                  24   AIC:                                      59.20
# Df Residuals:                      23   BIC:                                      60.38
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          0.1862      0.005     39.373      0.000       0.176       0.196
# ==============================================================================
# Omnibus:                        0.701   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.704   Jarque-Bera (JB):                0.670
# Skew:                          -0.034   Prob(JB):                        0.715
# Kurtosis:                       2.184   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.919
# Model:                            OLS   Adj. R-squared (uncentered):              0.916
# Method:                 Least Squares   F-statistic:                              261.5
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    4.69e-14
# Time:                        03:37:13   Log-Likelihood:                         -8.0520
# No. Observations:                  24   AIC:                                      18.10
# Df Residuals:                      23   BIC:                                      19.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lot            0.1802      0.011     16.170      0.000       0.157       0.203
# ==============================================================================
# Omnibus:                        1.193   Durbin-Watson:                   1.521
# Prob(Omnibus):                  0.551   Jarque-Bera (JB):                0.876
# Skew:                          -0.453   Prob(JB):                        0.645
# Kurtosis:                       2.766   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.979
# Method:                 Least Squares   F-statistic:                              1096.
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    6.59e-21
# Time:                        03:37:13   Log-Likelihood:                          8.3818
# No. Observations:                  24   AIC:                                     -14.76
# Df Residuals:                      23   BIC:                                     -13.59
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# size           0.8356      0.025     33.105      0.000       0.783       0.888
# ==============================================================================
# Omnibus:                        0.519   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.772   Jarque-Bera (JB):                0.626
# Skew:                          -0.260   Prob(JB):                        0.731
# Kurtosis:                       2.404   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.831
# Model:                            OLS   Adj. R-squared (uncentered):              0.824
# Method:                 Least Squares   F-statistic:                              113.4
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    2.31e-10
# Time:                        03:37:13   Log-Likelihood:                         -16.874
# No. Observations:                  24   AIC:                                      35.75
# Df Residuals:                      23   BIC:                                      36.93
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# garage         0.7538      0.071     10.648      0.000       0.607       0.900
# ==============================================================================
# Omnibus:                        0.407   Durbin-Watson:                   2.423
# Prob(Omnibus):                  0.816   Jarque-Bera (JB):                0.532
# Skew:                           0.012   Prob(JB):                        0.766
# Kurtosis:                       2.271   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.970
# Model:                            OLS   Adj. R-squared (uncentered):              0.969
# Method:                 Least Squares   F-statistic:                              747.2
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    4.85e-19
# Time:                        03:37:13   Log-Likelihood:                          3.9004
# No. Observations:                  24   AIC:                                     -5.801
# Df Residuals:                      23   BIC:                                     -4.623
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rooms          0.1788      0.007     27.336      0.000       0.165       0.192
# ==============================================================================
# Omnibus:                        3.003   Durbin-Watson:                   1.566
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                2.271
# Skew:                           0.749   Prob(JB):                        0.321
# Kurtosis:                       2.830   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.961
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              561.1
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.17e-17
# Time:                        03:37:13   Log-Likelihood:                         0.58165
# No. Observations:                  24   AIC:                                     0.8367
# Df Residuals:                      23   BIC:                                      2.015
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bedrooms       0.3629      0.015     23.688      0.000       0.331       0.395
# ==============================================================================
# Omnibus:                        0.242   Durbin-Watson:                   1.227
# Prob(Omnibus):                  0.886   Jarque-Bera (JB):                0.196
# Skew:                           0.183   Prob(JB):                        0.907
# Kurtosis:                       2.752   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.834
# Model:                            OLS   Adj. R-squared (uncentered):              0.827
# Method:                 Least Squares   F-statistic:                              115.7
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.90e-10
# Time:                        03:37:13   Log-Likelihood:                         -16.672
# No. Observations:                  24   AIC:                                      35.34
# Df Residuals:                      23   BIC:                                      36.52
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.0272      0.003     10.756      0.000       0.022       0.032
# ==============================================================================
# Omnibus:                        0.673   Durbin-Watson:                   0.904
# Prob(Omnibus):                  0.714   Jarque-Bera (JB):                0.729
# Skew:                           0.321   Prob(JB):                        0.695
# Kurtosis:                       2.437   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.276
# Model:                            OLS   Adj. R-squared (uncentered):              0.244
# Method:                 Least Squares   F-statistic:                              8.756
# Date:                Sun, 02 May 2021   Prob (F-statistic):                     0.00703
# Time:                        03:37:13   Log-Likelihood:                         -34.363
# No. Observations:                  24   AIC:                                      70.73
# Df Residuals:                      23   BIC:                                      71.90
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# fire           1.2500      0.422      2.959      0.007       0.376       2.124
# ==============================================================================
# Omnibus:                        3.689   Durbin-Watson:                   0.863
# Prob(Omnibus):                  0.158   Jarque-Bera (JB):                3.005
# Skew:                          -0.855   Prob(JB):                        0.223
# Kurtosis:                       2.719   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   bath   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.979
# Method:                 Least Squares   F-statistic:                              1120.
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    5.15e-21
# Time:                        03:37:13   Log-Likelihood:                          8.6388
# No. Observations:                  24   AIC:                                     -15.28
# Df Residuals:                      23   BIC:                                     -14.10
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          0.0335      0.001     33.469      0.000       0.031       0.036
# ==============================================================================
# Omnibus:                        5.802   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                3.752
# Skew:                          -0.870   Prob(JB):                        0.153
# Kurtosis:                       3.849   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.938
# Model:                            OLS   Adj. R-squared (uncentered):              0.935
# Method:                 Least Squares   F-statistic:                              346.3
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    2.31e-15
# Time:                        03:37:13   Log-Likelihood:                         -45.035
# No. Observations:                  24   AIC:                                      92.07
# Df Residuals:                      23   BIC:                                      93.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# size           4.3493      0.234     18.610      0.000       3.866       4.833
# ==============================================================================
# Omnibus:                        1.117   Durbin-Watson:                   1.519
# Prob(Omnibus):                  0.572   Jarque-Bera (JB):                1.001
# Skew:                          -0.314   Prob(JB):                        0.606
# Kurtosis:                       2.221   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.799
# Model:                            OLS   Adj. R-squared (uncentered):              0.791
# Method:                 Least Squares   F-statistic:                              91.66
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.73e-09
# Time:                        03:37:13   Log-Likelihood:                         -59.071
# No. Observations:                  24   AIC:                                      120.1
# Df Residuals:                      23   BIC:                                      121.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# garage         3.9321      0.411      9.574      0.000       3.082       4.782
# ==============================================================================
# Omnibus:                       10.893   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               10.498
# Skew:                           1.018   Prob(JB):                      0.00525
# Kurtosis:                       5.521   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.922
# Model:                            OLS   Adj. R-squared (uncentered):              0.918
# Method:                 Least Squares   F-statistic:                              271.4
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    3.17e-14
# Time:                        03:37:13   Log-Likelihood:                         -47.757
# No. Observations:                  24   AIC:                                      97.51
# Df Residuals:                      23   BIC:                                      98.69
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rooms          0.9271      0.056     16.473      0.000       0.811       1.044
# ==============================================================================
# Omnibus:                        0.056   Durbin-Watson:                   0.938
# Prob(Omnibus):                  0.973   Jarque-Bera (JB):                0.167
# Skew:                          -0.096   Prob(JB):                        0.920
# Kurtosis:                       2.640   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.896
# Model:                            OLS   Adj. R-squared (uncentered):              0.891
# Method:                 Least Squares   F-statistic:                              197.8
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    8.76e-13
# Time:                        03:37:13   Log-Likelihood:                         -51.209
# No. Observations:                  24   AIC:                                      104.4
# Df Residuals:                      23   BIC:                                      105.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bedrooms       1.8643      0.133     14.063      0.000       1.590       2.139
# ==============================================================================
# Omnibus:                        1.267   Durbin-Watson:                   0.868
# Prob(Omnibus):                  0.531   Jarque-Bera (JB):                1.128
# Skew:                          -0.477   Prob(JB):                        0.569
# Kurtosis:                       2.532   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.735
# Model:                            OLS   Adj. R-squared (uncentered):              0.724
# Method:                 Least Squares   F-statistic:                              63.91
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    4.34e-08
# Time:                        03:37:13   Log-Likelihood:                         -62.396
# No. Observations:                  24   AIC:                                      126.8
# Df Residuals:                      23   BIC:                                      128.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.1361      0.017      7.994      0.000       0.101       0.171
# ==============================================================================
# Omnibus:                        0.515   Durbin-Watson:                   0.777
# Prob(Omnibus):                  0.773   Jarque-Bera (JB):                0.590
# Skew:                           0.060   Prob(JB):                        0.744
# Kurtosis:                       2.241   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.310
# Model:                            OLS   Adj. R-squared (uncentered):              0.280
# Method:                 Least Squares   F-statistic:                              10.34
# Date:                Sun, 02 May 2021   Prob (F-statistic):                     0.00384
# Time:                        03:37:13   Log-Likelihood:                         -73.894
# No. Observations:                  24   AIC:                                      149.8
# Df Residuals:                      23   BIC:                                      151.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# fire           7.0520      2.193      3.215      0.004       2.515      11.589
# ==============================================================================
# Omnibus:                        1.686   Durbin-Watson:                   0.874
# Prob(Omnibus):                  0.430   Jarque-Bera (JB):                1.452
# Skew:                          -0.555   Prob(JB):                        0.484
# Kurtosis:                       2.534   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    lot   R-squared (uncentered):                   0.945
# Model:                            OLS   Adj. R-squared (uncentered):              0.943
# Method:                 Least Squares   F-statistic:                              397.2
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    5.22e-16
# Time:                        03:37:13   Log-Likelihood:                         -43.487
# No. Observations:                  24   AIC:                                      88.97
# Df Residuals:                      23   BIC:                                      90.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          0.1753      0.009     19.929      0.000       0.157       0.193
# ==============================================================================
# Omnibus:                        9.721   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                7.704
# Skew:                           1.133   Prob(JB):                       0.0212
# Kurtosis:                       4.603   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   size   R-squared (uncentered):                   0.852
# Model:                            OLS   Adj. R-squared (uncentered):              0.845
# Method:                 Least Squares   F-statistic:                              132.3
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    5.13e-11
# Time:                        03:37:13   Log-Likelihood:                         -19.379
# No. Observations:                  24   AIC:                                      40.76
# Df Residuals:                      23   BIC:                                      41.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
# ...
# Kurtosis:                       3.231   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  rooms   R-squared (uncentered):                   0.271
# Model:                            OLS   Adj. R-squared (uncentered):              0.240
# Method:                 Least Squares   F-statistic:                              8.571
# Date:                Sun, 02 May 2021   Prob (F-statistic):                     0.00757
# Time:                        03:37:14   Log-Likelihood:                         -75.388
# No. Observations:                  24   AIC:                                      152.8
# Df Residuals:                      23   BIC:                                      154.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# fire           6.8333      2.334      2.928      0.008       2.005      11.662
# ==============================================================================
# Omnibus:                        5.550   Durbin-Watson:                   0.716
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                4.853
# Skew:                          -1.091   Prob(JB):                       0.0883
# Kurtosis:                       2.690   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  rooms   R-squared (uncentered):                   0.978
# Model:                            OLS   Adj. R-squared (uncentered):              0.977
# Method:                 Least Squares   F-statistic:                              1021.
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.47e-20
# Time:                        03:37:14   Log-Likelihood:                         -33.409
# No. Observations:                  24   AIC:                                      68.82
# Df Residuals:                      23   BIC:                                      70.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          0.1846      0.006     31.947      0.000       0.173       0.197
# ==============================================================================
# Omnibus:                        1.478   Durbin-Watson:                   0.891
# Prob(Omnibus):                  0.477   Jarque-Bera (JB):                1.102
# Skew:                           0.275   Prob(JB):                        0.576
# Kurtosis:                       2.106   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               bedrooms   R-squared (uncentered):                   0.890
# Model:                            OLS   Adj. R-squared (uncentered):              0.885
# Method:                 Least Squares   F-statistic:                              186.0
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.65e-12
# Time:                        03:37:14   Log-Likelihood:                         -35.595
# No. Observations:                  24   AIC:                                      73.19
# Df Residuals:                      23   BIC:                                      74.37
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.0760      0.006     13.639      0.000       0.064       0.088
# ==============================================================================
# Omnibus:                        0.423   Durbin-Watson:                   1.148
# Prob(Omnibus):                  0.809   Jarque-Bera (JB):                0.328
# Skew:                           0.257   Prob(JB):                        0.849
# Kurtosis:                       2.748   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               bedrooms   R-squared (uncentered):                   0.243
# Model:                            OLS   Adj. R-squared (uncentered):              0.210
# Method:                 Least Squares   F-statistic:                              7.367
# Date:                Sun, 02 May 2021   Prob (F-statistic):                      0.0124
# Time:                        03:37:14   Log-Likelihood:                         -58.745
# No. Observations:                  24   AIC:                                      119.5
# Df Residuals:                      23   BIC:                                      120.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# fire           3.1667      1.167      2.714      0.012       0.753       5.580
# ==============================================================================
# Omnibus:                        5.228   Durbin-Watson:                   0.715
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                4.365
# Skew:                          -1.041   Prob(JB):                        0.113
# Kurtosis:                       2.823   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               bedrooms   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.957
# Method:                 Least Squares   F-statistic:                              538.0
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    1.87e-17
# Time:                        03:37:14   Log-Likelihood:                         -23.748
# No. Observations:                  24   AIC:                                      49.50
# Df Residuals:                      23   BIC:                                      50.67
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          0.0896      0.004     23.195      0.000       0.082       0.098
# ==============================================================================
# Omnibus:                        2.188   Durbin-Watson:                   1.047
# Prob(Omnibus):                  0.335   Jarque-Bera (JB):                1.400
# Skew:                           0.592   Prob(JB):                        0.496
# Kurtosis:                       2.996   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    age   R-squared (uncentered):                   0.288
# Model:                            OLS   Adj. R-squared (uncentered):              0.257
# Method:                 Least Squares   F-statistic:                              9.308
# Date:                Sun, 02 May 2021   Prob (F-statistic):                     0.00567
# Time:                        03:37:14   Log-Likelihood:                         -118.45
# No. Observations:                  24   AIC:                                      238.9
# Df Residuals:                      23   BIC:                                      240.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# fire          42.8333     14.039      3.051      0.006      13.790      71.876
# ==============================================================================
# Omnibus:                        0.684   Durbin-Watson:                   0.697
# Prob(Omnibus):                  0.710   Jarque-Bera (JB):                0.723
# Skew:                          -0.334   Prob(JB):                        0.697
# Kurtosis:                       2.474   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    age   R-squared (uncentered):                   0.815
# Model:                            OLS   Adj. R-squared (uncentered):              0.807
# Method:                 Least Squares   F-statistic:                              101.1
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    6.90e-10
# Time:                        03:37:14   Log-Likelihood:                         -102.30
# No. Observations:                  24   AIC:                                      206.6
# Df Residuals:                      23   BIC:                                      207.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          1.0253      0.102     10.054      0.000       0.814       1.236
# ==============================================================================
# Omnibus:                        0.741   Durbin-Watson:                   0.939
# Prob(Omnibus):                  0.690   Jarque-Bera (JB):                0.788
# Skew:                          -0.319   Prob(JB):                        0.674
# Kurtosis:                       2.383   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   fire   R-squared (uncentered):                   0.283
# Model:                            OLS   Adj. R-squared (uncentered):              0.251
# Method:                 Least Squares   F-statistic:                              9.063
# Date:                Sun, 02 May 2021   Prob (F-statistic):                     0.00623
# Time:                        03:37:14   Log-Likelihood:                         -13.432
# No. Observations:                  24   AIC:                                      28.86
# Df Residuals:                      23   BIC:                                      30.04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sales          0.0076      0.003      3.010      0.006       0.002       0.013
# ==============================================================================
# Omnibus:                        6.140   Durbin-Watson:                   2.752
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.579
# Skew:                           1.134   Prob(JB):                       0.0615
# Kurtosis:                       2.343   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Did the resulting model differ from the one you arrived at in part 1?  Why or why not?  Do you prefer yours to the automated process?  (Ideally you do!)

# %% [markdown]
# ***
# The resulting model differed a little bit from the one I arrived at in part 1, but the difference was not too significant. The reason behind this difference may be attributed to the increased amount of calculations in the automated process. I do prefer mine to the automated process.

# %% [markdown]
# ---
# [Back to top](#top)
# <a id='bot'></a>
